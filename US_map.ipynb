# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#import datetime 
# %matplotlib inline

#importing the libraries for doing a geographical plot
#import geopandas as gpd
#from shapely.geometry import Point, Polygon
#import descartes
#from pyproj import CRS

#from matplotlib.dates import DateFormatter
#import matplotlib.dates as mdates

# %%
import plotly.graph_objs as go 
from plotly.offline import init_notebook_mode,iplot,plot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_confirmed_US = pd.read_csv('time_series_covid_19_confirmed_US.csv')
df_deaths_US = pd.read_csv('time_series_covid_19_deaths_US.csv')

# %%
df_deaths_US.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  \
# 0 -14.2710 -170.1320  ...       0        0        0        0        0
# 1  13.4443  144.7937  ...       1        1        1        1        1
# 2  15.0979  145.6739  ...       0        0        0        0        0
# 3  18.2208  -66.5901  ...       2        2        2        3        3
# 4  18.3358  -64.8963  ...       0        0        0        0        0
#
#    3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# ...

# %%
df_confirmed_US_1 = df_confirmed_US[df_confirmed_US['iso2']=='US']
df_confirmed_US_1 = df_confirmed_US_1.groupby('Province_State').sum().reset_index()

df_confirmed_US_1 = df_confirmed_US_1.drop(['UID','code3','FIPS','Lat','Long_'],axis=1)

df_confirmed_US_1 = df_confirmed_US_1[df_confirmed_US_1['Province_State']!= 'Diamond Princess']
df_confirmed_US_1 = df_confirmed_US_1[df_confirmed_US_1['Province_State']!='Grand Princess']

# %%
state_codes = {
    'District of Columbia' : 'dc','Mississippi': 'MS', 'Oklahoma': 'OK', 
    'Delaware': 'DE', 'Minnesota': 'MN', 'Illinois': 'IL', 'Arkansas': 'AR', 
    'New Mexico': 'NM', 'Indiana': 'IN', 'Maryland': 'MD', 'Louisiana': 'LA', 
    'Idaho': 'ID', 'Wyoming': 'WY', 'Tennessee': 'TN', 'Arizona': 'AZ', 
    'Iowa': 'IA', 'Michigan': 'MI', 'Kansas': 'KS', 'Utah': 'UT', 
    'Virginia': 'VA', 'Oregon': 'OR', 'Connecticut': 'CT', 'Montana': 'MT', 
    'California': 'CA', 'Massachusetts': 'MA', 'West Virginia': 'WV', 
    'South Carolina': 'SC', 'New Hampshire': 'NH', 'Wisconsin': 'WI',
    'Vermont': 'VT', 'Georgia': 'GA', 'North Dakota': 'ND', 
    'Pennsylvania': 'PA', 'Florida': 'FL', 'Alaska': 'AK', 'Kentucky': 'KY', 
    'Hawaii': 'HI', 'Nebraska': 'NE', 'Missouri': 'MO', 'Ohio': 'OH', 
    'Alabama': 'AL', 'Rhode Island': 'RI', 'South Dakota': 'SD', 
    'Colorado': 'CO', 'New Jersey': 'NJ', 'Washington': 'WA', 
    'North Carolina': 'NC', 'New York': 'NY', 'Texas': 'TX', 
    'Nevada': 'NV', 'Maine': 'ME'}

df_confirmed_US_1['state_code'] = df_confirmed_US_1['Province_State'].apply(lambda x : state_codes[x])

# %%
data = dict(type='choropleth',
            locations = df_confirmed_US_1['state_code'],
            locationmode = 'USA-states',
            colorscale = ["yellow","blue","green","violet","orange","red"],
            #text = df_confirmed_US_1['Province_State'],
            z = df_confirmed_US_1['4/2/20'],
            colorbar = {'title':'Confirmed'}
            )

layout = dict(title = 'Confirmed Cases in US',
              geo = dict(scope='usa')
             )

choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="1e67629d-4dfc-4a08-af73-3e8448e721b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e67629d-4dfc-4a08-af73-3e8448e721b5")) {
#                     Plotly.newPlot(
#                         '1e67629d-4dfc-4a08-af73-3e8448e721b5',
# ...

# %%
df_deaths_US_1 = df_deaths_US[df_confirmed_US['iso2']=='US']

df_deaths_US_1 = df_deaths_US_1.groupby('Province_State').sum().reset_index()

df_deaths_US_1 = df_deaths_US_1.drop(['UID','code3','FIPS','Lat','Long_','Population'],axis=1)

df_deaths_US_1 = df_deaths_US_1[df_deaths_US_1['Province_State']!= 'Diamond Princess']
df_deaths_US_1 = df_deaths_US_1[df_deaths_US_1['Province_State']!='Grand Princess']

df_deaths_US_1['state_code'] = df_deaths_US_1['Province_State'].apply(lambda x : state_codes[x])

# %%
data = dict(type='choropleth',
            locations = df_deaths_US_1['state_code'],
            locationmode = 'USA-states',
            colorscale = ["yellow","blue","green","violet","orange","red"],
            z = df_deaths_US_1['4/2/20'],
            colorbar = {'title':'Deaths'}
            )

layout = dict(title = 'Deaths from Coronavirus in US',
              geo = dict(scope='usa')
             )

choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="1b2b421d-3c85-4980-87f2-8070204f28ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b2b421d-3c85-4980-87f2-8070204f28ba")) {
#                     Plotly.newPlot(
#                         '1b2b421d-3c85-4980-87f2-8070204f28ba',
# ...

# %%
df_confirmed_US_2 = df_confirmed_US[df_confirmed_US['iso2']=='US']

df_confirmed_US_2 = df_confirmed_US_2.drop(['UID','code3','FIPS','Country_Region','iso3'],axis=1)

df_confirmed_US_2 = df_confirmed_US_2[df_confirmed_US_2['4/2/20']!= 0]

# %%
data = go.Scattergeo(
        lon = df_confirmed_US_2['Long_'],
        lat = df_confirmed_US_2['Lat'],
        text = df_confirmed_US_2['4/2/20'],
        mode = 'markers',
        marker = dict(symbol = 'circle',size=5,colorscale = ["yellow","blue","green","violet","orange","red"]
                      ),
        marker_color = df_confirmed_US_2['4/2/20']
        )
layout = dict(title = 'Confirmed Cases',
              geo_scope = 'usa'
             )
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="b77c4c01-5085-47dd-b694-4410592826b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b77c4c01-5085-47dd-b694-4410592826b6")) {
#                     Plotly.newPlot(
#                         'b77c4c01-5085-47dd-b694-4410592826b6',
# ...

# %%
df_deaths_US_2 = df_deaths_US[df_deaths_US['iso2']=='US']

df_deaths_US_2 = df_deaths_US_2.drop(['UID','code3','FIPS','Country_Region','iso3'],axis=1)

df_deaths_US_2 = df_deaths_US_2[df_deaths_US_2['4/2/20']!= 0]

# %%
data = go.Scattergeo(
        lon = df_deaths_US_2['Long_'],
        lat = df_deaths_US_2['Lat'],
        text = df_deaths_US_2['4/2/20'],
        mode = 'markers',
        marker = dict(symbol = 'circle',size=5,colorscale = ["yellow","blue","green","violet","orange","red"]
                      ),
        marker_color = df_deaths_US_2['4/2/20']
        )
layout = dict(title = 'Deaths from Coronavirus',
              geo_scope = 'usa'
             )
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="3c26c2d8-428a-4eae-80c3-2bdfd155b069" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c26c2d8-428a-4eae-80c3-2bdfd155b069")) {
#                     Plotly.newPlot(
#                         '3c26c2d8-428a-4eae-80c3-2bdfd155b069',
# ...
